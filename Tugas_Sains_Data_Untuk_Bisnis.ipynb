# %% [markdown]
# <a href="https://colab.research.google.com/github/RhesaAP/Tugas-/blob/main/Tugas_Sains_Data_Untuk_Bisnis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("Data Covid19.csv")
data.head()
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  1/22/2020 17:00        444      17
# 1          Hubei  Mainland China    1/23/20 17:00        444      17
# 2          Hubei  Mainland China    1/23/20 17:00        444      17
# 3          Hubei  Mainland China    1/24/20 17:00        549      24
# 4          Hubei  Mainland China    1/25/20 17:00        761      40
#
#    Recovered
# 0         28
# 1         28
# 2         28
# 3         31
# 4         32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114358 entries, 0 to 114357
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  114358 non-null  object
#  1   Country/Region  114358 non-null  object
#  2   Last Update     114358 non-null  object
#  3   Confirmed       114358 non-null  int64
#  4   Deaths          114358 non-null  int64
#  5   Recovered       114358 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 5.2+ MB

# %%
data['Last Update'].unique()
# Out:
# array(['1/22/2020 17:00', '1/23/20 17:00', '1/24/20 17:00', ...,
#        '26/02/2021 05.22', '27/02/2021 05.22', '28/02/2021 05.22'],
#       dtype=object)

# %%
latest_date = '28/02/2021 05.22'
data[data['Last Update']==latest_date]
# Out:
#             Province/State  Country/Region       Last Update  Confirmed  \
# 113959             Abruzzo           Italy  28/02/2021 05.22      53900
# 113960                Acre          Brazil  28/02/2021 05.22      57337
# 113961     Adygea Republic          Russia  28/02/2021 05.22      13772
# 113962               Aichi           Japan  28/02/2021 05.22      25858
# 113963               Akita           Japan  28/02/2021 05.22        269
# ...                    ...             ...               ...        ...
# 114353    Zabaykalsky Krai          Russia  28/02/2021 05.22      38523
# 114354  Zakarpattia Oblast         Ukraine  28/02/2021 05.22      39830
# 114355   Zaporizhia Oblast         Ukraine  28/02/2021 05.22      69504
# 114356            Zhejiang  Mainland China  28/02/2021 05.22       1321
# 114357     Zhytomyr Oblast         Ukraine  28/02/2021 05.22      50582
#
#         Deaths  Recovered
# 113959    1698      39479
# 113960     996      46623
# 113961     149      12159
# 113962     515      24524
# 113963       6        260
# ...        ...        ...
# 114353     528      36849
# 114354     900      30516
# 114355    1132      65049
# 114356       1       1314
# 114357     834      44309
#
# [399 rows x 6 columns]

# %%
unique_countries = data[data.Confirmed>0]['Country/Region'].unique()
unique_countries.sort()
unique_countries
# Out:
# array(['Australia', 'Brazil', 'Canada', 'Chile', 'Colombia', 'Denmark',
#        'France', 'Germany', 'Hong Kong', 'India', 'Italy', 'Japan',
#        'Mainland China', 'Mexico', 'Netherlands', 'Others', 'Pakistan',
#        'Peru', 'Russia', 'Spain', 'Taiwan', 'UK', 'US', 'Ukraine'],
#       dtype=object)

# %%
country_confirmed_case = []
for i in unique_countries:
  country_confirmed_case.append(data[data.Confirmed>0][data['Country/Region']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(set(zip(unique_countries, country_confirmed_case)))
# Out:
# {('Brazil', 10517232), ('Mainland China', 88855), ('India', 11096731), ('Ukraine', 1389570), ('Denmark', 658), ('Chile', 821418), ('Peru', 7500), ('Others', 0), ('UK', 12177), ('Russia', 4187166), ('Japan', 430795), ('Australia', 23688), ('Pakistan', 579973), ('Mexico', 0), ('Germany', 2442582), ('Italy', 2907825), ('Hong Kong', 10983), ('Spain', 3188553), ('US', 0), ('Netherlands', 14854), ('Colombia', 2248135), ('France', 83122), ('Taiwan', 0), ('Canada', 869154)}

# %%
unique_provinces = data['Province/State'][data.Confirmed>1].unique()
unique_provinces
# Out:
# array(['Hubei', 'Shanghai', 'Beijing', 'Henan', 'Sichuan', 'Hainan',
#        'Chongqing', 'Heilongjiang', 'Hebei', 'Tianjin', 'Guizhou',
#        'Guangdong', 'Jilin', 'Hunan', 'Gansu', 'Anhui', 'Shandong',
#        'Guangxi', 'Jiangxi', 'Liaoning', 'Hong Kong', 'Xinjiang',
#        'Taiwan', 'Yunnan', 'Zhejiang', 'Diamond Princess cruise ship',
#        'Fujian', 'Shaanxi', 'Seattle, WA', 'King County, WA',
#        'Inner Mongolia', 'New South Wales', 'British Columbia',
#        'Washington', 'California', 'France', 'UK', 'United Kingdom',
#        'Denmark', 'Netherlands', 'New Jersey', 'Kentucky', 'Ontario',
#        'Illinois', 'Western Australia', 'French Polynesia', 'Curacao',
#        'Queensland', 'Victoria', 'Guadeloupe',
#        'Australian Capital Territory', 'St Martin', 'Martinique',
#        'Mayotte', 'Tasmania', 'Sint Maarten', 'Channel Islands',
#        'Cayman Islands', 'Bermuda', 'Isle of Man', 'South Australia',
#        'Aruba', 'British Virgin Islands', 'French Guiana',
#        'Turks and Caicos Islands', 'Montserrat', 'Abruzzo', 'Alberta',
#        'Andalusia', 'Aragon', 'Asturias', 'Baden-Wurttemberg', 'Baleares',
#        'Basilicata', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen',
#        'C. Valenciana', 'Calabria', 'Campania', 'Canarias', 'Cantabria',
#        'Castilla - La Mancha', 'Castilla y Leon', 'Catalonia', 'Ceuta',
#        'Emilia-Romagna', 'Extremadura', 'Friuli Venezia Giulia',
#        'Galicia', 'Hamburg', 'Hessen', 'La Rioja', 'Lazio', 'Liguria',
#        'Lombardia', 'Madrid', 'Manitoba', 'Marche',
#        'Mecklenburg-Vorpommern', 'Melilla', 'Molise', 'Murcia', 'Navarra',
#        'Newfoundland and Labrador', 'Niedersachsen',
#        'Nordrhein-Westfalen', 'Nova Scotia', 'P.A. Bolzano',
#        'P.A. Trento', 'Pais Vasco', 'Piemonte', 'Puglia', 'Quebec',
#        'Rheinland-Pfalz', 'Saarland', 'Sachsen', 'Sachsen-Anhalt',
#        'Sardegna', 'Saskatchewan', 'Schleswig-Holstein', 'Sicilia',
#        'Thuringen', 'Toscana', 'Umbria', 'Unknown', "Valle d'Aosta",
#        'Veneto', 'Aguascalientes', 'Baja California',
#        'Baja California Sur', 'Campeche', 'Chiapas', 'Chihuahua',
#        'Ciudad de Mexico', 'Coahuila', 'Colima', 'Durango', 'Guanajuato',
#        'Guerrero', 'Hidalgo', 'Jalisco', 'Mexico', 'Michoacan', 'Morelos',
#        'Nayarit', 'Nuevo Leon', 'Oaxaca', 'Puebla', 'Queretaro',
#        'Quintana Roo', 'Reunion', 'San Luis Potosi', 'Sinaloa', 'Sonora',
#        'Tabasco', 'Tamaulipas', 'Tlaxcala', 'Veracruz', 'Yucatan',
#        'Zacatecas', 'Aichi', 'Amazonas', 'Antioquia', 'Aomori',
#        'Atlantico', 'Bolivar', 'Boyaca', 'Caldas', 'Capital District',
#        'Caqueta', 'Cauca', 'Cesar', 'Chiba', 'Choco', 'Cordoba',
#        'Cundinamarca', 'Ehime', 'Fukui', 'Fukuoka', 'Gifu', 'Gunma',
#        'Hiroshima', 'Hokkaido', 'Huila', 'Hyogo', 'Ibaraki', 'Ishikawa',
#        'Kanagawa', 'Kochi', 'Kumamoto', 'Kyoto', 'La Guajira',
#        'Magdalena', 'Meta', 'Mie', 'Miyagi', 'Nagasaki', 'Nara', 'Narino',
#        'Norte de Santander', 'Oita', 'Okinawa', 'Osaka', 'Quindio',
#        'Risaralda', 'Saitama', 'Santander', 'Shiga', 'Shizuoka',
#        'Tokushima', 'Tokyo', 'Tolima', 'Toyama', 'Valle del Cauca',
#        'Wakayama', 'Yamanashi', 'Putumayo', 'Adygea Republic',
#        'Altai Krai', 'Amur Oblast', 'Arkhangelsk Oblast',
#        'Astrakhan Oblast', 'Bashkortostan Republic', 'Belgorod Oblast',
#        'Bryansk Oblast', 'Buryatia Republic', 'Chechen Republic',
#        'Chelyabinsk Oblast', 'Cherkasy Oblast', 'Chernihiv Oblast',
#        'Chernivtsi Oblast', 'Chukotka Autonomous Okrug',
#        'Chuvashia Republic', 'Crimea Republic*', 'Dagestan Republic',
#        'Dnipropetrovsk Oblast', 'Donetsk Oblast', 'Ingushetia Republic',
#        'Irkutsk Oblast', 'Ivano-Frankivsk Oblast', 'Ivanovo Oblast',
#        'Jewish Autonomous Okrug', 'Kabardino-Balkarian Republic',
#        'Kaliningrad Oblast', 'Kalmykia Republic', 'Kaluga Oblast',
#        'Kamchatka Krai', 'Karachay-Cherkess Republic', 'Karelia Republic',
#        'Kemerovo Oblast', 'Khabarovsk Krai', 'Khakassia Republic',
#        'Khanty-Mansi Autonomous Okrug', 'Kharkiv Oblast',
#        'Kherson Oblast', 'Khmelnytskyi Oblast', 'Kiev', 'Kiev Oblast',
#        'Kirov Oblast', 'Kirovohrad Oblast', 'Komi Republic',
#        'Kostroma Oblast', 'Krasnodar Krai', 'Krasnoyarsk Krai',
#        'Kursk Oblast', 'Leningrad Oblast', 'Lipetsk Oblast',
#        'Lviv Oblast', 'Magadan Oblast', 'Mari El Republic',
#        'Mordovia Republic', 'Moscow', 'Moscow Oblast', 'Murmansk Oblast',
#        'Mykolaiv Oblast', 'Nizhny Novgorod Oblast',
#        'North Ossetia - Alania Republic', 'Novgorod Oblast',
#        'Novosibirsk Oblast', 'Odessa Oblast', 'Omsk Oblast',
#        'Orel Oblast', 'Orenburg Oblast', 'Penza Oblast', 'Perm Krai',
#        'Poltava Oblast', 'Primorsky Krai', 'Pskov Oblast', 'Rivne Oblast',
#        'Rostov Oblast', 'Ryazan Oblast', 'Saint Petersburg',
#        'Sakha (Yakutiya) Republic', 'Samara Oblast', 'Saratov Oblast',
#        'Sevastopol*', 'Smolensk Oblast', 'Stavropol Krai', 'Sumy Oblast',
#        'Sverdlovsk Oblast', 'Tambov Oblast', 'Tatarstan Republic',
#        'Ternopil Oblast', 'Tomsk Oblast', 'Tula Oblast', 'Tver Oblast',
#        'Tyumen Oblast', 'Tyva Republic', 'Udmurt Republic',
#        'Ulyanovsk Oblast', 'Vinnytsia Oblast', 'Vladimir Oblast',
#        'Volgograd Oblast', 'Vologda Oblast', 'Volyn Oblast',
#        'Voronezh Oblast', 'Yamalo-Nenets Autonomous Okrug',
#        'Yaroslavl Oblast', 'Zabaykalsky Krai', 'Zakarpattia Oblast',
#        'Zaporizhia Oblast', 'Zhytomyr Oblast', 'New Brunswick',
#        'Casanare', 'Sucre', 'Acre', 'Alagoas', 'Amapa', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Maranhao', 'Mato Grosso',
#        'Mato Grosso do Sul', 'Minas Gerais', 'Para', 'Paraiba', 'Parana',
#        'Pernambuco', 'Piaui', 'Rio Grande do Norte', 'Rio Grande do Sul',
#        'Rio de Janeiro', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins', 'Michigan', 'Andhra Pradesh',
#        'Assam', 'Azad Jammu and Kashmir', 'Balochistan', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Delhi', 'Gilgit-Baltistan',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Islamabad',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Khyber Pakhtunkhwa', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Meghalaya', 'Odisha', 'Punjab', 'Rajasthan', 'Sindh',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Puducherry', 'Guainia',
#        'San Andres y Providencia', 'Goa', 'Port Quarantine',
#        'Arunachal Pradesh', 'Kurgan Oblast', 'Antofagasta', 'Araucania',
#        'Arica y Parinacota', 'Atacama', 'Biobio', 'Coquimbo', 'Los Lagos',
#        'Los Rios', 'Magallanes', 'Maule', 'Metropolitana', 'Nuble',
#        'OHiggins', 'Tarapaca', 'Valparaiso', 'Altai Republic', 'Vaupes',
#        'Yamagata', 'Goias', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Luhansk Oblast', 'Aysen', 'Arauca', 'Nagaland',
#        'Andaman and Nicobar Islands', 'Sikkim', 'Kagoshima', 'Manipur',
#        'Tochigi', 'Miyazaki', 'Kagawa', 'Vichada', 'Guaviare', 'Okayama',
#        'Nagano', 'Yamaguchi', 'Bonaire, Sint Eustatius and Saba',
#        'Fukushima', 'Nenets Autonomous Okrug', 'Sakhalin Oblast', 'Saga',
#        'Mizoram', 'Yukon', 'Gibraltar', 'Iwate', 'Akita',
#        'Saint Barthelemy', 'Niigata', 'Nunavut', 'Faroe Islands',
#        'Tottori', 'Lakshadweep'], dtype=object)

# %%
province_confirmed_case = []
for i in unique_provinces:
  province_confirmed_case.append(data[data.Confirmed>0][data['Province/State']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(set(zip(unique_provinces, province_confirmed_case)))
# Out:
# {('Altai Republic', 16181), ('Castilla - La Mancha', 168561), ('New Jersey', 0), ('Quindio', 32019), ('Santander', 90875), ('Ryazan Oblast', 24415), ('Galicia', 111461), ('Port Quarantine', 2230), ('King County, WA', 0), ('Kharkiv Oblast', 83539), ('Ulyanovsk Oblast', 47590), ('Kherson Oblast', 21673), ('Nenets Autonomous Okrug', 1023), ('Quebec', 287003), ('Kostroma Oblast', 18358), ('France', 0), ('Voronezh Oblast', 67572), ('Sonora', 0), ('Yamaguchi', 1381), ('Bremen', 17997), ('Rivne Oblast', 48779), ('New South Wales', 0), ('Iwate', 554), ('Krasnodar Krai', 38275), ('Hamburg', 51665), ('Toscana', 155167), ('Kamchatka Krai', 13482), ('Gunma', 4492), ('Norte de Santander', 50712), ('Balochistan', 19045), ('Capital District', 657198), ('Bayern', 436473), ('Fujian', 551), ('Schleswig-Holstein', 42445), ('Cauca', 27343), ('British Columbia', 79194), ('Kagoshima', 1761), ('Nova Scotia', 1638), ('Tottori', 211), ('Bermuda', 705), ('Amazonas', 320626), ('Atacama', 11937), ('Lakshadweep', 359), ('Montserrat', 20), ('Tasmania', 234), ('Curacao', 4727), ('Shiga', 2462), ('UK', 0), ('Toyama', 908), ('British Virgin Islands', 153), ('Astrakhan Oblast', 28181), ('Assam', 217527), ('Sindh', 258004), ('Tabasco', 0), ('Kalmykia Republic', 18960), ('Xinjiang', 980), ('Chongqing', 591), ('Jalisco', 0), ('Chuvashia Republic', 21343), ('Liguria', 77730), ('Meghalaya', 13961), ('Asturias', 43179), ('Castilla y Leon', 205587), ('Guadeloupe', 9968), ('Kagawa', 749), ('Pskov Oblast', 31806), ('Ibaraki', 5745), ('Saratov Oblast', 49312), ('Para', 363916), ('Veracruz', 0), ('Alberta', 133203), ('Gifu', 4613), ('Khmelnytskyi Oblast', 47888), ('Catalonia', 577701), ('Kemerovo Oblast', 31584), ('Rostov Oblast', 72745), ('Kumamoto', 3441), ('Penza Oblast', 38139), ('Santa Catarina', 668811), ('West Bengal', 574926), ('Karachay-Cherkess Republic', 19012), ('Aragon', 106480), ('Leningrad Oblast', 35856), ('Altai Krai', 43399), ('Quintana Roo', 0), ('Guaviare', 2245), ('Hessen', 188380), ('Nunavut', 356), ('Gujarat', 269482), ('Andalusia', 476822), ('La Guajira', 16131), ('Goias', 395572), ('Sao Paulo', 2037267), ('Sinaloa', 0), ('Kabardino-Balkarian Republic', 20919), ('Chukotka Autonomous Okrug', 690), ('Western Australia', 913), ('Hubei', 68151), ('Mato Grosso do Sul', 180986), ('Dadra and Nagar Haveli and Daman and Diu', 3406), ('Ciudad de Mexico', 0), ('Belgorod Oblast', 31356), ('Odisha', 337104), ('Zhytomyr Oblast', 50582), ('Guizhou', 147), ('Islamabad', 44259), ('Tarapaca', 24658), ('Tolima', 65123), ('Mizoram', 4423), ('Stavropol Krai', 47228), ('Chernivtsi Oblast', 54383), ('Lazio', 232887), ('Volyn Oblast', 39901), ('Zabaykalsky Krai', 38523), ('Yaroslavl Oblast', 32668), ('Akita', 269), ('Gibraltar', 4238), ('North Ossetia - Alania Republic', 15677), ('Shaanxi', 551), ('Miyagi', 3650), ('Fukushima', 1948), ('Piemonte', 246232), ('Araucania', 39823), ('Jammu and Kashmir', 126383), ('Piaui', 173290), ('Henan', 1304), ('Sakha (Yakutiya) Republic', 32508), ('Diamond Princess cruise ship', 0), ('Ceuta', 4562), ('Niigata', 1077), ('Novosibirsk Oblast', 35635), ('Meta', 42297), ('Kaliningrad Oblast', 28111), ('Tambov Oblast', 26154), ('Rio Grande do Norte', 165344), ('Tripura', 33417), ('Michoacan', 0), ('Yamanashi', 941), ('Omsk Oblast', 40831), ('Guerrero', 0), ('Extremadura', 68952), ('Los Rios', 19182), ('French Polynesia', 18387), ('Madhya Pradesh', 261403), ('Sverdlovsk Oblast', 77513), ('Tocantins', 113594), ('Metropolitana', 364151), ('La Rioja', 27422), ('Martinique', 6746), ('Hunan', 1036), ('French Guiana', 16627), ('Cherkasy Oblast', 48588), ('Faroe Islands', 658), ('Smolensk Oblast', 26131), ('Ingushetia Republic', 14719), ('Parana', 643344), ('Manitoba', 31809), ('Nuble', 16844), ('Abruzzo', 53900), ('Cundinamarca', 105433), ('Amur Oblast', 20970), ('Chernihiv Oblast', 35829), ('Molise', 10547), ('Vichada', 1364), ('Nagasaki', 1610), ('Maharashtra', 2146777), ('Aruba', 7876), ('Chechen Republic', 11287), ('Shanghai', 1794), ('Turks and ...

# %%
nan_indices = []
for i in range(len(unique_provinces)):
  if type(unique_provinces[i])==float:
    nan_indices.append(i)

# %%
unique_provinces = list(unique_provinces)
province_confirmed_case = list(province_confirmed_case)

# %%
for i in nan_indices:
  unique_provinces.pop(i)
  province_confirmed_case.pop(i)

unique_provinces
# Out:
# ['Hubei',
#  'Shanghai',
#  'Beijing',
#  'Henan',
#  'Sichuan',
#  'Hainan',
#  'Chongqing',
#  'Heilongjiang',
#  'Hebei',
#  'Tianjin',
#  'Guizhou',
#  'Guangdong',
#  'Jilin',
#  'Hunan',
#  'Gansu',
#  'Anhui',
#  'Shandong',
#  'Guangxi',
#  'Jiangxi',
#  'Liaoning',
#  'Hong Kong',
#  'Xinjiang',
#  'Taiwan',
#  'Yunnan',
#  'Zhejiang',
#  'Diamond Princess cruise ship',
#  'Fujian',
#  'Shaanxi',
#  'Seattle, WA',
#  'King County, WA',
#  'Inner Mongolia',
#  'New South Wales',
#  'British Columbia',
#  'Washington',
#  'California',
#  'France',
#  'UK',
#  'United Kingdom',
#  'Denmark',
#  'Netherlands',
#  'New Jersey',
#  'Kentucky',
#  'Ontario',
#  'Illinois',
#  'Western Australia',
#  'French Polynesia',
#  'Curacao',
#  'Queensland',
#  'Victoria',
#  'Guadeloupe',
#  'Australian Capital Territory',
#  'St Martin',
#  'Martinique',
#  'Mayotte',
#  'Tasmania',
#  'Sint Maarten',
#  'Channel Islands',
#  'Cayman Islands',
#  'Bermuda',
#  'Isle of Man',
#  'South Australia',
#  'Aruba',
#  'British Virgin Islands',
#  'French Guiana',
#  'Turks and Caicos Islands',
#  'Montserrat',
#  'Abruzzo',
#  'Alberta',
#  'Andalusia',
#  'Aragon',
#  'Asturias',
#  'Baden-Wurttemberg',
#  'Baleares',
#  'Basilicata',
#  'Bayern',
#  'Berlin',
#  'Brandenburg',
#  'Bremen',
#  'C. Valenciana',
#  'Calabria',
#  'Campania',
#  'Canarias',
#  'Cantabria',
#  'Castilla - La Mancha',
#  'Castilla y Leon',
#  'Catalonia',
#  'Ceuta',
#  'Emilia-Romagna',
#  'Extremadura',
#  'Friuli Venezia Giulia',
#  'Galicia',
#  'Hamburg',
#  'Hessen',
#  'La Rioja',
#  'Lazio',
#  'Liguria',
#  'Lombardia',
#  'Madrid',
#  'Manitoba',
#  'Marche',
#  'Mecklenburg-Vorpommern',
#  'Melilla',
#  'Molise',
#  'Murcia',
#  'Navarra',
#  'Newfoundland and Labrador',
#  'Niedersachsen',
#  'Nordrhein-Westfalen',
#  'Nova Scotia',
#  'P.A. Bolzano',
#  'P.A. Trento',
#  'Pais Vasco',
#  'Piemonte',
#  'Puglia',
#  'Quebec',
#  'Rheinland-Pfalz',
#  'Saarland',
#  'Sachsen',
#  'Sachsen-Anhalt',
#  'Sardegna',
#  'Saskatchewan',
#  'Schleswig-Holstein',
#  'Sicilia',
#  'Thuringen',
#  'Toscana',
#  'Umbria',
#  'Unknown',
#  "Valle d'Aosta",
#  'Veneto',
#  'Aguascalientes',
#  'Baja California',
#  'Baja California Sur',
#  'Campeche',
#  'Chiapas',
#  'Chihuahua',
#  'Ciudad de Mexico',
#  'Coahuila',
#  'Colima',
#  'Durango',
#  'Guanajuato',
#  'Guerrero',
#  'Hidalgo',
#  'Jalisco',
#  'Mexico',
#  'Michoacan',
#  'Morelos',
#  'Nayarit',
#  'Nuevo Leon',
#  'Oaxaca',
#  'Puebla',
#  'Queretaro',
#  'Quintana Roo',
#  'Reunion',
#  'San Luis Potosi',
#  'Sinaloa',
#  'Sonora',
#  'Tabasco',
#  'Tamaulipas',
#  'Tlaxcala',
#  'Veracruz',
#  'Yucatan',
#  'Zacatecas',
#  'Aichi',
#  'Amazonas',
#  'Antioquia',
#  'Aomori',
#  'Atlantico',
#  'Bolivar',
#  'Boyaca',
#  'Caldas',
#  'Capital District',
#  'Caqueta',
#  'Cauca',
#  'Cesar',
#  'Chiba',
#  'Choco',
#  'Cordoba',
#  'Cundinamarca',
#  'Ehime',
#  'Fukui',
#  'Fukuoka',
#  'Gifu',
#  'Gunma',
#  'Hiroshima',
#  'Hokkaido',
#  'Huila',
#  'Hyogo',
#  'Ibaraki',
#  'Ishikawa',
#  'Kanagawa',
#  'Kochi',
#  'Kumamoto',
#  'Kyoto',
#  'La Guajira',
#  'Magdalena',
#  'Meta',
#  'Mie',
#  'Miyagi',
#  'Nagasaki',
#  'Nara',
#  'Narino',
#  'Norte de Santander',
#  'Oita',
#  'Okinawa',
#  'Osaka',
#  'Quindio',
#  'Risaralda',
#  'Saitama',
#  'Santander',
#  'Shiga',
#  'Shizuoka',
#  'Tokushima',
#  'Tokyo',
#  'Tolima',
#  'Toyama',
#  'Valle del Cauca',
#  'Wakayama',
#  'Yamanashi',
#  'Putumayo',
#  'Adygea Republic',
#  'Altai Krai',
#  'Amur Oblast',
#  'Arkhangelsk Oblast',
#  'Astrakhan Oblast',
#  'Bashkortostan Republic',
#  'Belgorod Oblast',
#  'Bryansk Oblast',
#  'Buryatia Republic',
#  'Chechen Republic',
#  'Chelyabinsk Oblast',
#  'Cherkasy Oblast',
#  'Chernihiv Oblast',
#  'Chernivtsi Oblast',
#  'Chukotka Autonomous Okrug',
#  'Chuvashia Republic',
#  'Crimea Republic*',
#  'Dagestan Republic',
#  'Dnipropetrovsk Oblast',
#  'Donetsk Oblast',
#  'Ingushetia Republic',
#  'Irkutsk Oblast',
#  'Ivano-Frankivsk Oblast',
#  'Ivanovo Oblast',
#  'Jewish Autonomous Okrug',
#  'Kabardino-Balkarian Republic',
#  'Kaliningrad Oblast',
#  'Kalmykia Republic',
#  'Kaluga Oblast',
#  'Kamchatka Krai',
#  'Karachay-Cherkess Republic',
#  'Karelia Republic',
#  'Kemerovo Oblast',
#  'Khabarovsk Krai',
#  'Khakassia Republic',
#  'Khanty-Mansi Autonomous Okrug',
#  'Kharkiv Oblast',
#  'Kherson Oblast',
#  'Khmelnytskyi Oblast',
#  'Kiev',
#  'Kiev Oblast',
#  'Kirov Oblast',
#  'Kirovohrad Oblast',
#  'Komi Republic',
#  'Kostroma Oblast',
#  'Krasnodar Krai',
#  'Krasnoyarsk Krai',
#  'Kursk Oblast',
#  'Leningrad Oblast',
#  'Lipetsk Oblast',
#  'Lviv Oblast',
#  'Magadan Oblast',
#  'Mari El Republic',
#  'Mordovia Republic',
#  'Moscow',
#  'Moscow Oblast',
#  'Murmansk Oblast',
#  'Mykolaiv Oblast',
#  'Nizhny Novgorod Oblast',
#  'North Ossetia - Alania Republic',
#  'Novgorod Oblast',
#  'Novosibirsk Oblast',
#  'Odessa Oblast',
#  'Omsk Oblast',
#  'Orel Oblast',
#  'Orenburg Oblast',
#  'Penza Oblast',
#  'Perm Krai',
#  'Poltava Oblast',
#  'Primorsky Krai',
#  'Pskov Oblast',
#  'Rivne Oblast',
#  'Rostov Oblast',
#  'Ryazan Oblast',
#  'Saint Petersburg',
#  'Sakha (Yakutiya) Republic',
#  'Samara Oblast',
#  'Saratov Oblast',
#  'Sevastopol*',
#  'Smolensk Oblast',
#  'Stavropol Krai',
#  'Sumy Oblast',
#  'Sverdlovsk Oblast',
#  'Tambov Oblast',
#  'Tatarstan Republic',
#  'Ternopil Oblast',
#  'Tomsk Oblast',
#  'Tula Oblast',
#  'Tver Oblast',
#  'Tyumen Oblast',
#  'Tyva Republic',
#  'Udmurt Republic',
#  'Ulyanovsk Oblast',
#  'Vinnytsia Oblast',
#  'Vladimir Oblast',
#  'Volgograd Oblast',
#  'Vologda Oblast',
#  'Volyn Oblast',
#  'Voronezh Oblast',
#  'Yamalo-Nenets Autonomous Okrug',
#  'Yaroslavl Oblast',
#  'Zabaykalsky Krai',
#  'Zakarpattia Oblast',
#  'Zaporizhia Oblast',
#  'Zhytomyr Oblast',
#  'New Brunswick',
#  'Casanare',
#  'Sucre',
#  'Acre',
#  'Alagoas',
#  'Amapa',
#  'Bahia',
#  'Ceara',
#  'Distrito Federal',
#  'Espirito Santo',
#  'Maranhao',
#  'Mato Grosso',
#  'Mato Grosso do Sul',
#  'Minas Gerais',
#  'Para',
#  'Paraiba',
#  'Parana',
#  'Pernambuco',
#  'Piaui',
#  'Rio Grande do Norte',
#  'Rio Grande do Sul',
#  'Rio de Janeiro',
#  'Rondonia',
#  'Roraima',
#  'Santa Catarina',
#  'Sao Paulo',
#  'Sergipe',
#  'Tocantins',
#  'Michigan',
#  'Andhra Pradesh',
#  'Assam',
#  'Azad Jammu and Kashmir',
#  'Balochistan',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Delhi',
#  'Gilgit-Baltistan',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Islamabad',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Khyber Pakhtunkhwa',
#  'Ladakh',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Meghalaya',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sindh',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'Puducherry',
#  'Guainia',
#  'San Andres y Providencia',
#  'Goa',
#  'Port Quarantine',
#  'Arunachal Pradesh',
#  'Kurgan Oblast',
#  'Antofagasta',
#  'Araucania',
#  'Arica y Parinacota',
#  'Atacama',
#  'Biobio',
#  'Coquimbo',
#  'Los Lagos',
#  'Los Rios',
#  'Magallanes',
#  'Maule',
#  'Metropolitana',
#  'Nuble',
#  'OHiggins',
#  'Tarapaca',
#  'Valparaiso',
#  'Altai Republic',
#  'Vaupes',
#  'Yamagata',
#  'Goias',
#  'Dadra and Nagar Haveli and Daman and Diu',
#  'Luhansk Oblast',
#  'Aysen',
#  'Arauca',
#  'Nagaland',
#  'Andaman and Nicobar Islands',
#  'Sikkim',
#  'Kagoshima',
#  'Manipur',
#  'Tochigi',
#  'Miyazaki',
#  'Kagawa',
#  'Vichada',
#  'Guaviare',
#  'Okayama',
#  'Nagano',
#  'Yamaguchi',
#  'Bonaire, Sint Eustatius and Saba',
#  'Fukushima',
#  'Nenets Autonomous Okrug',
#  'Sakhalin Oblast',
#  'Saga',
#  'Mizoram',
#  'Yukon',
#  'Gibraltar',
#  'Iwate',
#  'Akita',
#  'Saint Barthelemy',
#  'Niigata',
#  'Nunavut',
#  'Faroe Islands',
#  'Tottori',
#  'Lakshadweep']

# %%
plt.barh(unique_countries, country_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(50,40))
plt.barh(unique_provinces, province_confirmed_case)
plt.show()
